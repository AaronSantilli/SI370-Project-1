# %%
import pandas as pd

# %%
data = pd.read_csv('nyc_real_estate.csv', index_col=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       387 non-null    int64
#  1   Name             387 non-null    object
#  2   City             387 non-null    object
#  3   Neighbourhood    387 non-null    object
#  4   Price            387 non-null    object
#  5   Year Built       387 non-null    object
#  6   Beds             387 non-null    object
#  7   Baths            387 non-null    object
#  8   Area             387 non-null    object
#  9   Price(per sqft)  387 non-null    object
#  10  A/C              387 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 33.4+ KB

# %%
data = data.drop(labels = ['Unnamed: 0'], axis = 1)

# %%
data['cleaned_year'] = data['Year Built'].apply(lambda x : x[-4:])
data.head()
# Out:
#                      Name                        City    Neighbourhood  \
# 0  3324 Junction Blvd #5X   Jackson Heights, NY 11372  Jackson Heights
# 1       37-26 32nd St #5K  Long Island City, NY 11101          Astoria
# 2       37-26 32nd St #3G  Long Island City, NY 11101          Astoria
# 3       37-26 32nd St #6L  Long Island City, NY 11101          Astoria
# 4       37-26 32nd St #3H  Long Island City, NY 11101          Astoria
#
#        Price        Year Built    Beds   Baths      Area Price(per sqft)  \
# 0  $285,000               Null   1 Bed  1 Bath  800 sqft           $356
# 1  $620,000   Year Built: 2022  Studio  1 Bath  441 sqft         $1,406
# 2  $730,000   Year Built: 2022   1 Bed  1 Bath  579 sqft         $1,261
# 3  $570,000   Year Built: 2022  Studio  1 Bath  429 sqft         $1,329
# 4  $695,000   Year Built: 2022   1 Bed  1 Bath  632 sqft         $1,100
#
#             A/C cleaned_year
# 0  Cooling only         Null
# 1  Cooling only         2022
# 2  Cooling only         2022
# 3  Cooling only         2022
# 4            No         2022

# %%
data = data.replace("Null", pd.NA).dropna()

# %%
data
# Out:
#                           Name                        City  \
# 1            37-26 32nd St #5K  Long Island City, NY 11101
# 2            37-26 32nd St #3G  Long Island City, NY 11101
# 3            37-26 32nd St #6L  Long Island City, NY 11101
# 4            37-26 32nd St #3H  Long Island City, NY 11101
# 6    2736 Independence Ave #6J             Bronx, NY 10463
# ..                         ...                         ...
# 379           1619 3rd Ave #3B          New York, NY 10128
# 381            43 Joralemon St          Brooklyn, NY 11201
# 382         195 Classon Ave #5          Brooklyn, NY 11205
# 384       410 Maryland Ave #1C     Staten Island, NY 10305
# 385             2415 E 64th St          Brooklyn, NY 11234
#
#           Neighbourhood        Price        Year Built    Beds    Baths  \
# 1               Astoria    $620,000   Year Built: 2022  Studio   1 Bath
# 2               Astoria    $730,000   Year Built: 2022   1 Bed   1 Bath
# 3               Astoria    $570,000   Year Built: 2022  Studio   1 Bath
# 4               Astoria    $695,000   Year Built: 2022   1 Bed   1 Bath
# 6        Spuyten Duyvil    $235,995   Year Built: 1970   1 Bed   1 Bath
# ..                  ...          ...               ...     ...      ...
# 379     Upper East Side    $635,000   Year Built: 1975  Studio   1 Bath
# 381    Brooklyn Heights  $4,500,000   Year Built: 1845  5 Beds  6 Baths
# 382  Bedford Stuyvesant  $1,395,000   Year Built: 2008  2 Beds  2 Baths
# 384            Rosebank    $279,900   Year Built: 1974  2 Beds   1 Bath
# 385          Mill Basin  $1,089,000   Year Built: 1965  4 Beds  3 Baths
#
#            Area Price(per sqft)                A/C cleaned_year
# 1      441 sqft         $1,406        Cooling only         2022
# 2      579 sqft         $1,261        Cooling only         2022
# 3      429 sqft         $1,329        Cooling only         2022
# 4      632 sqft         $1,100                  No         2022
# 6      850 sqft           $278                  No         1970
# ..          ...             ...                ...          ...
# 379    528 sqft         $1,203        Cooling only         1975
# 381  3,192 sqft         $1,410                  No         1845
# 382  1,185 sqft         $1,177                  No         2008
# 384  1,100 sqft           $254   Heating & Cooling         1974
# 385  1,899 sqft           $573   Heating & Cooling         1965
#
# [251 rows x 11 columns]

# %%
data['Price'] = data['Price'].str.replace('$', '')
# Out:
# /var/folders/bm/7gfzqmk92w7f0g15qhnh3_1h0000gn/T/ipykernel_10178/813483522.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Price'] = data['Price'].str.replace('$', '')

# %%
data
# Out:
#                           Name                        City  \
# 1            37-26 32nd St #5K  Long Island City, NY 11101
# 2            37-26 32nd St #3G  Long Island City, NY 11101
# 3            37-26 32nd St #6L  Long Island City, NY 11101
# 4            37-26 32nd St #3H  Long Island City, NY 11101
# 6    2736 Independence Ave #6J             Bronx, NY 10463
# ..                         ...                         ...
# 379           1619 3rd Ave #3B          New York, NY 10128
# 381            43 Joralemon St          Brooklyn, NY 11201
# 382         195 Classon Ave #5          Brooklyn, NY 11205
# 384       410 Maryland Ave #1C     Staten Island, NY 10305
# 385             2415 E 64th St          Brooklyn, NY 11234
#
#           Neighbourhood       Price        Year Built    Beds    Baths  \
# 1               Astoria    620,000   Year Built: 2022  Studio   1 Bath
# 2               Astoria    730,000   Year Built: 2022   1 Bed   1 Bath
# 3               Astoria    570,000   Year Built: 2022  Studio   1 Bath
# 4               Astoria    695,000   Year Built: 2022   1 Bed   1 Bath
# 6        Spuyten Duyvil    235,995   Year Built: 1970   1 Bed   1 Bath
# ..                  ...         ...               ...     ...      ...
# 379     Upper East Side    635,000   Year Built: 1975  Studio   1 Bath
# 381    Brooklyn Heights  4,500,000   Year Built: 1845  5 Beds  6 Baths
# 382  Bedford Stuyvesant  1,395,000   Year Built: 2008  2 Beds  2 Baths
# 384            Rosebank    279,900   Year Built: 1974  2 Beds   1 Bath
# 385          Mill Basin  1,089,000   Year Built: 1965  4 Beds  3 Baths
#
#            Area Price(per sqft)                A/C cleaned_year
# 1      441 sqft         $1,406        Cooling only         2022
# 2      579 sqft         $1,261        Cooling only         2022
# 3      429 sqft         $1,329        Cooling only         2022
# 4      632 sqft         $1,100                  No         2022
# 6      850 sqft           $278                  No         1970
# ..          ...             ...                ...          ...
# 379    528 sqft         $1,203        Cooling only         1975
# 381  3,192 sqft         $1,410                  No         1845
# 382  1,185 sqft         $1,177                  No         2008
# 384  1,100 sqft           $254   Heating & Cooling         1974
# 385  1,899 sqft           $573   Heating & Cooling         1965
#
# [251 rows x 11 columns]

# %%
data['Baths'] = data['Baths'].str.replace('Baths', '')

# %%
data
# Out:
#                           Name                        City  \
# 1            37-26 32nd St #5K  Long Island City, NY 11101
# 2            37-26 32nd St #3G  Long Island City, NY 11101
# 3            37-26 32nd St #6L  Long Island City, NY 11101
# 4            37-26 32nd St #3H  Long Island City, NY 11101
# 6    2736 Independence Ave #6J             Bronx, NY 10463
# ..                         ...                         ...
# 379           1619 3rd Ave #3B          New York, NY 10128
# 381            43 Joralemon St          Brooklyn, NY 11201
# 382         195 Classon Ave #5          Brooklyn, NY 11205
# 384       410 Maryland Ave #1C     Staten Island, NY 10305
# 385             2415 E 64th St          Brooklyn, NY 11234
#
#           Neighbourhood       Price        Year Built    Beds   Baths  \
# 1               Astoria    620,000   Year Built: 2022  Studio  1 Bath
# 2               Astoria    730,000   Year Built: 2022   1 Bed  1 Bath
# 3               Astoria    570,000   Year Built: 2022  Studio  1 Bath
# 4               Astoria    695,000   Year Built: 2022   1 Bed  1 Bath
# 6        Spuyten Duyvil    235,995   Year Built: 1970   1 Bed  1 Bath
# ..                  ...         ...               ...     ...     ...
# 379     Upper East Side    635,000   Year Built: 1975  Studio  1 Bath
# 381    Brooklyn Heights  4,500,000   Year Built: 1845  5 Beds      6
# 382  Bedford Stuyvesant  1,395,000   Year Built: 2008  2 Beds      2
# 384            Rosebank    279,900   Year Built: 1974  2 Beds  1 Bath
# 385          Mill Basin  1,089,000   Year Built: 1965  4 Beds      3
#
#            Area Price(per sqft)                A/C cleaned_year
# 1      441 sqft         $1,406        Cooling only         2022
# 2      579 sqft         $1,261        Cooling only         2022
# 3      429 sqft         $1,329        Cooling only         2022
# 4      632 sqft         $1,100                  No         2022
# 6      850 sqft           $278                  No         1970
# ..          ...             ...                ...          ...
# 379    528 sqft         $1,203        Cooling only         1975
# 381  3,192 sqft         $1,410                  No         1845
# 382  1,185 sqft         $1,177                  No         2008
# 384  1,100 sqft           $254   Heating & Cooling         1974
# 385  1,899 sqft           $573   Heating & Cooling         1965
#
# [251 rows x 11 columns]

# %%
data['Baths'] = data['Baths'].str.replace('Bath', '')

# %%
data
# Out:
#                           Name                        City  \
# 1            37-26 32nd St #5K  Long Island City, NY 11101
# 2            37-26 32nd St #3G  Long Island City, NY 11101
# 3            37-26 32nd St #6L  Long Island City, NY 11101
# 4            37-26 32nd St #3H  Long Island City, NY 11101
# 6    2736 Independence Ave #6J             Bronx, NY 10463
# ..                         ...                         ...
# 379           1619 3rd Ave #3B          New York, NY 10128
# 381            43 Joralemon St          Brooklyn, NY 11201
# 382         195 Classon Ave #5          Brooklyn, NY 11205
# 384       410 Maryland Ave #1C     Staten Island, NY 10305
# 385             2415 E 64th St          Brooklyn, NY 11234
#
#           Neighbourhood       Price        Year Built    Beds Baths  \
# 1               Astoria    620,000   Year Built: 2022  Studio    1
# 2               Astoria    730,000   Year Built: 2022   1 Bed    1
# 3               Astoria    570,000   Year Built: 2022  Studio    1
# 4               Astoria    695,000   Year Built: 2022   1 Bed    1
# 6        Spuyten Duyvil    235,995   Year Built: 1970   1 Bed    1
# ..                  ...         ...               ...     ...   ...
# 379     Upper East Side    635,000   Year Built: 1975  Studio    1
# 381    Brooklyn Heights  4,500,000   Year Built: 1845  5 Beds    6
# 382  Bedford Stuyvesant  1,395,000   Year Built: 2008  2 Beds    2
# 384            Rosebank    279,900   Year Built: 1974  2 Beds    1
# 385          Mill Basin  1,089,000   Year Built: 1965  4 Beds    3
#
#            Area Price(per sqft)                A/C cleaned_year
# 1      441 sqft         $1,406        Cooling only         2022
# 2      579 sqft         $1,261        Cooling only         2022
# 3      429 sqft         $1,329        Cooling only         2022
# 4      632 sqft         $1,100                  No         2022
# 6      850 sqft           $278                  No         1970
# ..          ...             ...                ...          ...
# 379    528 sqft         $1,203        Cooling only         1975
# 381  3,192 sqft         $1,410                  No         1845
# 382  1,185 sqft         $1,177                  No         2008
# 384  1,100 sqft           $254   Heating & Cooling         1974
# 385  1,899 sqft           $573   Heating & Cooling         1965
#
# [251 rows x 11 columns]
